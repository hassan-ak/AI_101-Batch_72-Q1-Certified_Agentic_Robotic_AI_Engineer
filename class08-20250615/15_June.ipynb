# %%
words = ["apple", "kiwi", "banana"]
words.sort(key=len,reverse=True)
print(words)
# Out:
# ['banana', 'apple', 'kiwi']

# %%
words = ["apple", "kiwi", "banana"]
words.sort(key=lambda word: word[-2])
print(words)
# Out:
# ['apple', 'banana', 'kiwi']

# %%
numbers = [1, 2, 3,1,2,3]
print(numbers)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
print((1,2,3,4,1,2))
# Out:
# (1, 2, 3, 4, 1, 2)

# %%
my_set: set = {123, 452, 5, 6}
my_set2: set = set([123, 452, 5, 6])
unknown: set = {} # set or dectionary
empty_set: set = set()

# %%
my_set: set = {123, 452, 5, 6,6,7,5,5,5,5,5,5}
print(my_set)
# Out:
# {452, 5, 6, 7, 123}

# %%
my_set = {123, 452.0, 5.5, 6.6,True,False,"A","B","C","C",True,6.6} # TypeError: unhashable type: 'list'
print(len(my_set))
print(my_set)
# Out:
# 9
# {False, True, 452.0, 5.5, 6.6, 'C', 'A', 123, 'B'}

# %%
my_set[0] = 10  # Sets are unordered, so indexing doesn't work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3908351206> in <cell line: 0>()
# ----> 1 my_set[0] = 10  # Sets are unordered, so indexing doesn't work
#
# TypeError: 'set' object does not support item assignment

# %%
try:
    my_set[0] = 10  # Sets are unordered, so indexing doesn't work
except TypeError as e:
    print(e)
# Out:
# 'set' object does not support item assignment

# %%
my_set: set = {123, 452, 5, 6,6,7,5,5,5,5,5,5}
print(my_set)
my_set.add(55)
print(my_set)

my_set.update([55,5,555,"A"])
print(my_set)

my_set.discard(5345678987654323456789)
print(my_set)
# Out:
# {452, 5, 6, 7, 123}
# {452, 5, 6, 7, 55, 123}
# {'A', 452, 5, 6, 7, 55, 555, 123}
# {'A', 452, 5, 6, 7, 55, 555, 123}

# %%
number=[1,2,3,4,5,5]
print(number.pop(14567))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-3258031917> in <cell line: 0>()
#       1 number=[1,2,3,4,5,5]
# ----> 2 print(number.pop(14567))
#
# IndexError: pop index out of range

# %%
my_set: set = {123, 452, 5, 6,6,7,5,5,5,5,5,5}
my_set={"Jahanzaib"}
my_set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-2888128642> in <cell line: 0>()
#       1 my_set: set = {123, 452, 5, 6,6,7,5,5,5,5,5,5}
# ----> 2 my_set[0]
#
# TypeError: 'set' object is not subscriptable

# %%
forzenset= {1,2,3,4,5,6}
forzenset=set([1,2,3,4,5,6])
forzenset=frozenset([1,2,3,4,5,6])
print(forzenset)
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %%
import math
print(math)
print(math.sqrt(25))
# Out:
# <module 'math' (built-in)>
# 5.0

# %%
import os
print(os)
# Out:
# <module 'os' (frozen)>

# %%
import numpy as np
